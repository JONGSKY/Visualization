# %%
import os
import pandas as pd

# %%
import pandas as pd
import glob

# %%
BASE_DIR = os. getcwd()

# %%
BASE_DIR = os. getcwd()
all_files = glob.glob(BASE_DIR + "/*.xls")

li = []

for filename in all_files:
    df = pd.read_excel(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
df
# Out:
#       분류   고유번호                                 상호명  \
# 0     맛집    347                             Tartine
# 1     맛집    414                   Restaurant Indoro
# 2     맛집    434  Jinjinbara (Seoul Station Branch)
# 3     맛집    482   Jukmiin-Rice Porridge Restaurant
# 4     맛집    484                            Haerang
# ...   ..    ...                                 ...
# 1928  쇼핑  25749                     CJ Olive Market
# 1929  쇼핑  26039                        Tong-in Shop
# 1930  쇼핑   9766       Travel Ground (always market)
# 1931  쇼핑    282                       Tongin Market
# 1932  쇼핑   6451                   Chungcheongdo Jip
#
#                                                      주소  \
# 0      140-863 119-15, Itaewon-dong, Yongsan-gu, Seoul
# 1       110-300 198-36 Gwanhun-dong, Jongno-gu, Seoul
# 2     140-709 12, Dongja-dong, Yongsan-gu, Seoul, Ko...
# 3        121-807 106-83 Nogosan-dong, Mapo-gu, Seoul 1층
# 4        135-827 183 Nonhyeon-dong, Gangnam-gu, Seoul
# ...                                                 ...
# 1928
# 1929         110-300 16 Gwanhun-dong, Jongno-gu, Seoul
# 1930         121-874 Yeomni-dong, Mapo-gu, Seoul 169-12
# 1931        110-043 10-3 Tongin-dong, Jongno-gu, Seoul
# 1932            110-250 Jae-dong, Jongno-gu, Seoul 85-3
#
#                                                     신주소             전화번호  \
# 0        04350 4, Itaewon-ro 23-gil, Yongsan-gu, Seoul   +82-2-3785-3400
# 1     03149 20 Insadong 5-gil, Jongno-gu, Seoul (Gwa...   +82-2-738-7773
# 2     04323 107, Huam-ro, Yongsan-gu, Seoul, Korea (...   +82-2-777-8004
# 3        04100 12 Baekbeom-ro 2-gil, Mapo-gu, Seoul  1F   +82-2-719-9264
# 4     06120 12 Gangnamdaero-ro 118-gil, Gangnam-gu, ...   +82-2-544-7270
# ...                                                 ...              ...
# 1928  04560 B1 CJ Cheil Jedang Building 330 Dongho-r...              NaN
# 1929           03148 32 Insadong-gil, Jongno-gu, Seoul    +82-2-733-4867
# 1930     121-874 Baekbeom-ro 28-gil 17, Mapo-gu, Seoul               NaN
# 1931      03036 18 Jahamun-ro 15-gil, Jongno-gu, Seoul    +82-2-722-0911
# 1932         110-250 6-4, Bukchon-ro, Jongno-gu, Seoul    +82-2-734-8998
#
#                                                     TAG
# 0                                               Tartine
# 1                                     Restaurant Indoro
# 2         Traditional,Korean Food,Restaurant,Jinjinbara
# 3                      Jukmiin-Rice Porridge Restaurant
# 4                                               Haerang
# ...                                                 ...
# 1928  Bibigo,CJ Cheil Jedang,K-food,ParkBoGum,LifeSt...
# 1929  Handcraft Shop,Modern Craftwork,Oraegage,Galle...
# 1930                                                NaN
# 1931                                                NaN
# 1932                                                NaN
#
# [1933 rows x 7 columns]

# %%
frame
# Out:
#       분류   고유번호                            상호명  \
# 0     맛집    364                        Tartine
# 1     맛집    418                         通往印度之路
# 2     맛집    439                    津津罢漏(首尔站店)
# 3     맛집    486                           粥米人
# 4     맛집    506                 Pastel de nata
# ...   ..    ...                            ...
# 9706  쇼핑  25749                CJ Olive Market
# 9707  쇼핑  26039                   Tong-in Shop
# 9708  쇼핑   9766  Travel Ground (always market)
# 9709  쇼핑    282                  Tongin Market
# 9710  쇼핑   6451              Chungcheongdo Jip
#
#                                                주소  \
# 0                       140-863 首尔市龙山区梨泰院洞119-15
# 1                      110-300 서울 종로구 관훈동 198-36
# 2                          140-709 서울 용산구 동자동 12
# 3                   121-807 서울 마포구 노고산동 106-83 1층
# 4                      110-240 서울 종로구 안국동 175-57
# ...                                           ...
# 9706
# 9707   110-300 16 Gwanhun-dong, Jongno-gu, Seoul
# 9708   121-874 Yeomni-dong, Mapo-gu, Seoul 169-12
# 9709  110-043 10-3 Tongin-dong, Jongno-gu, Seoul
# 9710      110-250 Jae-dong, Jongno-gu, Seoul 85-3
#
#                                                     신주소            전화번호  \
# 0                                 04350 首尔市龙山区黎泰院路23街4     02-3785-3400
# 1                               03149 首尔市钟路区仁寺洞5街20号2楼   +82-2-738-7773
# 2                       04323 서울 용산구 후암로 107 (게이트웨이타워)   +82-2-777-8004
# 3                          04100 首尔市麻浦区白凡路2街12(老姑山洞) 1층  +82-2-719-9264
# 4                                 03061 서울 종로구 윤보선길 31      02-733-2979
# ...                                                 ...             ...
# 9706  04560 B1 CJ Cheil Jedang Building 330 Dongho-r...             NaN
# 9707           03148 32 Insadong-gil, Jongno-gu, Seoul   +82-2-733-4867
# 9708     121-874 Baekbeom-ro 28-gil 17, Mapo-gu, Seoul              NaN
# 9709      03036 18 Jahamun-ro 15-gil, Jongno-gu, Seoul   +82-2-722-0911
# 9710         110-250 6-4, Bukchon-ro, Jongno-gu, Seoul   +82-2-734-8998
#
#                                                     TAG
# 0                                               梨泰院·汝矣岛
# 1                                                通往印度之路
# 2                                            津津罢漏(首尔站店)
# 3                                               粥米人,营养粥
# 4                                               继承者,李敏镐
# ...                                                 ...
# 9706  Bibigo,CJ Cheil Jedang,K-food,ParkBoGum,LifeSt...
# 9707  Handcraft Shop,Modern Craftwork,Oraegage,Galle...
# 9708                                                NaN
# 9709                                                NaN
# 9710                                                NaN
#
# [9711 rows x 7 columns]

# %%
file_list = os.listdir()
print(file_list)
# Out:
# ['서울시_분류별_관광명소_현황(중국어_간체).xls', 'README.md', '서울시_분류별_관광명소_현황(한국어).xls', '.gitignore', 'Untitled.ipynb', '서울시_분류별_관광명소_현황(중국어_번체).xls', '서울시_분류별_관광명소_현황(일본어).xls', '.ipynb_checkpoints', '서울시_분류별_관광명소_현황(영어).xls']

# %%
for file_name in file_list:
    {} = pd.read_csv('')
